# %%
# %load_ext autoreload
# %autoreload 2

# %%
import yaml
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import copy
import pickle
from seaborn import histplot

# %%
os.chdir('/data/rsg/nlp/sdobers/amine/diffdock-protein/src')

from args import parse_args
from data import load_data, get_data
from data.data import BindingDataset
from model import load_model, to_cuda
from utils import printt, print_res, log, get_unixtime, compute_rmsd
from train import train, evaluate, evaluate_pose
from helpers import WandbLogger, TensorboardLogger
from sample import sample
from evaluation.compute_rmsd import evaluate_all_rmsds

# %%
from notebooks.utils_notebooks import Dict2Class

# %%
PATH = '/data/rsg/nlp/sdobers/amine/diffdock-protein/ckpts/dips_largest_model' # largest model

# %%
# load args
with open(os.path.join(PATH, 'args.yaml')) as f:
    args = yaml.safe_load(f)
args = Dict2Class(args)

args.num_gpu = 1
args.gpu = 5
args.data_file = args.data_file.replace('data_file', 'data_file_100_test')
args.checkpoint_path = PATH
#args.use_orientation_features = False
#args.recache = False
args.batch_size = 32
args.use_randomized_confidence_data = False
args.mode = "test"
if 'large' in PATH:
    args.batch_size = 4
#args.cross_cutoff_weight = 3
#args.cross_cutoff_bias = 40

# %%
args.data_file
# Out:
# '/data/rsg/nlp/sdobers/data/DIPS/data_file_100_test.csv'

# %%
data = load_data(args)
loaders = get_data(data, 0, args, for_reverse_diffusion=True)
# Out:
# data loading: 100%|█| 100/100 [00:00<00:00, 465516
# 05:28:20 Loaded cached ESM embeddings
# 05:28:20 finished tokenizing residues with ESM
# 05:28:20 finished tokenizing all inputs
# 05:28:20 100 entries loaded

# %%
loaders["test"].data = sorted(loaders["test"].data, key=lambda x:x['receptor_xyz'].shape[0] + x['ligand_xyz'].shape[0])

# %%
[comp["receptor"].pos.shape[0] + comp["ligand"].pos.shape[0] for comp in loaders["test"]]
# Out:
# [122,
#  126,
#  156,
#  159,
#  193,
#  207,
#  214,
#  219,
#  220,
#  222,
#  225,
#  234,
#  235,
#  237,
#  248,
#  255,
#  258,
#  259,
#  264,
#  265,
#  278,
#  280,
#  280,
#  286,
#  296,
#  298,
#  298,
#  300,
#  300,
#  302,
#  306,
#  308,
#  310,
#  311,
#  320,
#  329,
#  334,
#  338,
#  340,
#  344,
#  393,
#  395,
#  427,
#  428,
#  431,
#  431,
#  432,
#  443,
#  443,
#  446,
#  452,
#  506,
#  518,
#  520,
#  522,
#  523,
#  523,
#  526,
#  530,
#  530,
#  533,
#  562,
#  562,
#  597,
#  604,
#  605,
#  605,
#  608,
#  621,
#  624,
#  626,
#  638,
#  639,
#  659,
#  660,
#  678,
#  680,
#  760,
#  776,
#  818,
#  818,
#  840,
#  880,
#  924,
#  928,
#  928,
#  960,
#  1019,
#  1024,
#  1052,
#  1074,
#  1074,
#  1143,
#  1178,
#  1339,
#  1436,
#  1454,
#  1458,
#  1474,
#  1474]

# %%
loaders["test"][0:64]
# Out:
# BindingDataset(64)

# %%
[2,3,4] + [5,7,8]
# Out:
# [2, 3, 4, 5, 7, 8]

# %%
loaders["test"] = sorted(loaders["test"], key=lambda x:x["receptor"].pos.shape[0] + x["ligand"].pos.shape[0])

# %%
loaders["test"]
# Out:
# [HeteroData(
#    name='kq/1kq1.pdb1_2.dill',
#    center=[1, 3],
#    receptor={
#      pos=[61, 3],
#      x=[61, 1281]
#    },
#    ligand={
#      pos=[61, 3],
#      x=[61, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 1220] },
#    (ligand, contact, ligand)={ edge_index=[2, 1220] }
#  ),
#  HeteroData(
#    name='kq/1kq1.pdb1_1.dill',
#    center=[1, 3],
#    receptor={
#      pos=[66, 3],
#      x=[66, 1281]
#    },
#    ligand={
#      pos=[60, 3],
#      x=[60, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 1320] },
#    (ligand, contact, ligand)={ edge_index=[2, 1200] }
#  ),
#  HeteroData(
#    name='cf/5cff.pdb2_1.dill',
#    center=[1, 3],
#    receptor={
#      pos=[87, 3],
#      x=[87, 1281]
#    },
#    ligand={
#      pos=[69, 3],
#      x=[69, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 1740] },
#    (ligand, contact, ligand)={ edge_index=[2, 1380] }
#  ),
#  HeteroData(
#    name='dm/5dm7.pdb1_22.dill',
#    center=[1, 3],
#    receptor={
#      pos=[93, 3],
#      x=[93, 1281]
#    },
#    ligand={
#      pos=[66, 3],
#      x=[66, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 1860] },
#    (ligand, contact, ligand)={ edge_index=[2, 1320] }
#  ),
#  HeteroData(
#    name='p7/4p7s.pdb1_2.dill',
#    center=[1, 3],
#    receptor={
#      pos=[100, 3],
#      x=[100, 1281]
#    },
#    ligand={
#      pos=[93, 3],
#      x=[93, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2000] },
#    (ligand, contact, ligand)={ edge_index=[2, 1860] }
#  ),
#  HeteroData(
#    name='oi/2oie.pdb1_5.dill',
#    center=[1, 3],
#    receptor={
#      pos=[106, 3],
#      x=[106, 1281]
#    },
#    ligand={
#      pos=[101, 3],
#      x=[101, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2120] },
#    (ligand, contact, ligand)={ edge_index=[2, 2020] }
#  ),
#  HeteroData(
#    name='oi/4oiz.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[107, 3],
#      x=[107, 1281]
#    },
#    ligand={
#      pos=[107, 3],
#      x=[107, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2140] },
#    (ligand, contact, ligand)={ edge_index=[2, 2140] }
#  ),
#  HeteroData(
#    name='p7/2p7v.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[151, 3],
#      x=[151, 1281]
#    },
#    ligand={
#      pos=[68, 3],
#      x=[68, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 3020] },
#    (ligand, contact, ligand)={ edge_index=[2, 1360] }
#  ),
#  HeteroData(
#    name='tn/4tn5.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[110, 3],
#      x=[110, 1281]
#    },
#    ligand={
#      pos=[110, 3],
#      x=[110, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2200] },
#    (ligand, contact, ligand)={ edge_index=[2, 2200] }
#  ),
#  HeteroData(
#    name='sw/1swl.pdb1_5.dill',
#    center=[1, 3],
#    receptor={
#      pos=[111, 3],
#      x=[111, 1281]
#    },
#    ligand={
#      pos=[111, 3],
#      x=[111, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2220] },
#    (ligand, contact, ligand)={ edge_index=[2, 2220] }
#  ),
#  HeteroData(
#    name='eb/1ebo.pdb2_1.dill',
#    center=[1, 3],
#    receptor={
#      pos=[113, 3],
#      x=[113, 1281]
#    },
#    ligand={
#      pos=[112, 3],
#      x=[112, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2260] },
#    (ligand, contact, ligand)={ edge_index=[2, 2240] }
#  ),
#  HeteroData(
#    name='sw/1swp.pdb1_3.dill',
#    center=[1, 3],
#    receptor={
#      pos=[117, 3],
#      x=[117, 1281]
#    },
#    ligand={
#      pos=[117, 3],
#      x=[117, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2340] },
#    (ligand, contact, ligand)={ edge_index=[2, 2340] }
#  ),
#  HeteroData(
#    name='sw/1swd.pdb1_2.dill',
#    center=[1, 3],
#    receptor={
#      pos=[118, 3],
#      x=[118, 1281]
#    },
#    ligand={
#      pos=[117, 3],
#      x=[117, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2360] },
#    (ligand, contact, ligand)={ edge_index=[2, 2340] }
#  ),
#  HeteroData(
#    name='nq/1nqm.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[119, 3],
#      x=[119, 1281]
#    },
#    ligand={
#      pos=[118, 3],
#      x=[118, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2380] },
#    (ligand, contact, ligand)={ edge_index=[2, 2360] }
#  ),
#  HeteroData(
#    name='sk/3sk1.pdb2_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[124, 3],
#      x=[124, 1281]
#    },
#    ligand={
#      pos=[124, 3],
#      x=[124, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2480] },
#    (ligand, contact, ligand)={ edge_index=[2, 2480] }
#  ),
#  HeteroData(
#    name='j3/4j38.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[132, 3],
#      x=[132, 1281]
#    },
#    ligand={
#      pos=[123, 3],
#      x=[123, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2640] },
#    (ligand, contact, ligand)={ edge_index=[2, 2460] }
#  ),
#  HeteroData(
#    name='b2/2b2e.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[129, 3],
#      x=[129, 1281]
#    },
#    ligand={
#      pos=[129, 3],
#      x=[129, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2580] },
#    (ligand, contact, ligand)={ edge_index=[2, 2580] }
#  ),
#  HeteroData(
#    name='sl/1slt.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[129, 3],
#      x=[129, 1281]
#    },
#    ligand={
#      pos=[130, 3],
#      x=[130, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2580] },
#    (ligand, contact, ligand)={ edge_index=[2, 2600] }
#  ),
#  HeteroData(
#    name='sk/3sk2.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[132, 3],
#      x=[132, 1281]
#    },
#    ligand={
#      pos=[132, 3],
#      x=[132, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2640] },
#    (ligand, contact, ligand)={ edge_index=[2, 2640] }
#  ),
#  HeteroData(
#    name='nq/1nq3.pdb2_1.dill',
#    center=[1, 3],
#    receptor={
#      pos=[133, 3],
#      x=[133, 1281]
#    },
#    ligand={
#      pos=[132, 3],
#      x=[132, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2660] },
#    (ligand, contact, ligand)={ edge_index=[2, 2640] }
#  ),
#  HeteroData(
#    name='j3/1j30.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[141, 3],
#      x=[141, 1281]
#    },
#    ligand={
#      pos=[137, 3],
#      x=[137, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2820] },
#    (ligand, contact, ligand)={ edge_index=[2, 2740] }
#  ),
#  HeteroData(
#    name='cf/2cfx.pdb1_12.dill',
#    center=[1, 3],
#    receptor={
#      pos=[140, 3],
#      x=[140, 1281]
#    },
#    ligand={
#      pos=[140, 3],
#      x=[140, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2800] },
#    (ligand, contact, ligand)={ edge_index=[2, 2800] }
#  ),
#  HeteroData(
#    name='cf/2cfx.pdb1_7.dill',
#    center=[1, 3],
#    receptor={
#      pos=[140, 3],
#      x=[140, 1281]
#    },
#    ligand={
#      pos=[140, 3],
#      x=[140, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2800] },
#    (ligand, contact, ligand)={ edge_index=[2, 2800] }
#  ),
#  HeteroData(
#    name='aq/2aq6.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[143, 3],
#      x=[143, 1281]
#    },
#    ligand={
#      pos=[143, 3],
#      x=[143, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2860] },
#    (ligand, contact, ligand)={ edge_index=[2, 2860] }
#  ),
#  HeteroData(
#    name='nq/3nqn.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[149, 3],
#      x=[149, 1281]
#    },
#    ligand={
#      pos=[147, 3],
#      x=[147, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2980] },
#    (ligand, contact, ligand)={ edge_index=[2, 2940] }
#  ),
#  HeteroData(
#    name='s5/1s57.pdb1_8.dill',
#    center=[1, 3],
#    receptor={
#      pos=[149, 3],
#      x=[149, 1281]
#    },
#    ligand={
#      pos=[149, 3],
#      x=[149, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2980] },
#    (ligand, contact, ligand)={ edge_index=[2, 2980] }
#  ),
#  HeteroData(
#    name='s5/1s57.pdb1_4.dill',
#    center=[1, 3],
#    receptor={
#      pos=[149, 3],
#      x=[149, 1281]
#    },
#    ligand={
#      pos=[149, 3],
#      x=[149, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 2980] },
#    (ligand, contact, ligand)={ edge_index=[2, 2980] }
#  ),
#  HeteroData(
#    name='a9/1a95.pdb1_3.dill',
#    center=[1, 3],
#    receptor={
#      pos=[150, 3],
#      x=[150, 1281]
#    },
#    ligand={
#      pos=[150, 3],
#      x=[150, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 3000] },
#    (ligand, contact, ligand)={ edge_index=[2, 3000] }
#  ),
#  HeteroData(
#    name='s5/1s5z.pdb1_5.dill',
#    center=[1, 3],
#    receptor={
#      pos=[150, 3],
#      x=[150, 1281]
#    },
#    ligand={
#      pos=[150, 3],
#      x=[150, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 3000] },
#    (ligand, contact, ligand)={ edge_index=[2, 3000] }
#  ),
#  HeteroData(
#    name='s5/1s57.pdb2_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[153, 3],
#      x=[153, 1281]
#    },
#    ligand={
#      pos=[149, 3],
#      x=[149, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 3060] },
#    (ligand, contact, ligand)={ edge_index=[2, 2980] }
#  ),
#  HeteroData(
#    name='s5/1s57.pdb1_10.dill',
#    center=[1, 3],
#    receptor={
#      pos=[153, 3],
#      x=[153, 1281]
#    },
#    ligand={
#      pos=[153, 3],
#      x=[153, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 3060] },
#    (ligand, contact, ligand)={ edge_index=[2, 3060] }
#  ),
#  HeteroData(
#    name='nq/1nqu.pdb1_9.dill',
#    center=[1, 3],
#    receptor={
#      pos=[154, 3],
#      x=[154, 1281]
#    },
#    ligand={
#      pos=[154, 3],
#      x=[154, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 3080] },
#    (ligand, contact, ligand)={ edge_index=[2, 3080] }
#  ),
#  HeteroData(
#    name='aq/2aqp.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[155, 3],
#      x=[155, 1281]
#    },
#    ligand={
#      pos=[155, 3],
#      x=[155, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 3100] },
#    (ligand, contact, ligand)={ edge_index=[2, 3100] }
#  ),
#  HeteroData(
#    name='ww/1wwr.pdb3_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[157, 3],
#      x=[157, 1281]
#    },
#    ligand={
#      pos=[154, 3],
#      x=[154, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 3140] },
#    (ligand, contact, ligand)={ edge_index=[2, 3080] }
#  ),
#  HeteroData(
#    name='ww/1ww6.pdb2_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[160, 3],
#      x=[160, 1281]
#    },
#    ligand={
#      pos=[160, 3],
#      x=[160, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 3200] },
#    (ligand, contact, ligand)={ edge_index=[2, 3200] }
#  ),
#  HeteroData(
#    name='p7/3p7x.pdb1_1.dill',
#    center=[1, 3],
#    receptor={
#      pos=[166, 3],
#      x=[166, 1281]
#    },
#    ligand={
#      pos=[163, 3],
#      x=[163, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 3320] },
#    (ligand, contact, ligand)={ edge_index=[2, 3260] }
#  ),
#  HeteroData(
#    name='hm/3hm2.pdb2_3.dill',
#    center=[1, 3],
#    receptor={
#      pos=[169, 3],
#      x=[169, 1281]
#    },
#    ligand={
#      pos=[165, 3],
#      x=[165, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 3380] },
#    (ligand, contact, ligand)={ edge_index=[2, 3300] }
#  ),
#  HeteroData(
#    name='a9/3a98.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[186, 3],
#      x=[186, 1281]
#    },
#    ligand={
#      pos=[152, 3],
#      x=[152, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 3720] },
#    (ligand, contact, ligand)={ edge_index=[2, 3040] }
#  ),
#  HeteroData(
#    name='ed/2ed6.pdb4_1.dill',
#    center=[1, 3],
#    receptor={
#      pos=[170, 3],
#      x=[170, 1281]
#    },
#    ligand={
#      pos=[170, 3],
#      x=[170, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 3400] },
#    (ligand, contact, ligand)={ edge_index=[2, 3400] }
#  ),
#  HeteroData(
#    name='sw/3sw5.pdb1_8.dill',
#    center=[1, 3],
#    receptor={
#      pos=[172, 3],
#      x=[172, 1281]
#    },
#    ligand={
#      pos=[172, 3],
#      x=[172, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 3440] },
#    (ligand, contact, ligand)={ edge_index=[2, 3440] }
#  ),
#  HeteroData(
#    name='ww/4wwa.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[224, 3],
#      x=[224, 1281]
#    },
#    ligand={
#      pos=[169, 3],
#      x=[169, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 4480] },
#    (ligand, contact, ligand)={ edge_index=[2, 3380] }
#  ),
#  HeteroData(
#    name='ed/4edz.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[198, 3],
#      x=[198, 1281]
#    },
#    ligand={
#      pos=[197, 3],
#      x=[197, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 3960] },
#    (ligand, contact, ligand)={ edge_index=[2, 3940] }
#  ),
#  HeteroData(
#    name='dm/3dmp.pdb3_2.dill',
#    center=[1, 3],
#    receptor={
#      pos=[214, 3],
#      x=[214, 1281]
#    },
#    ligand={
#      pos=[213, 3],
#      x=[213, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 4280] },
#    (ligand, contact, ligand)={ edge_index=[2, 4260] }
#  ),
#  HeteroData(
#    name='dm/3dmp.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[214, 3],
#      x=[214, 1281]
#    },
#    ligand={
#      pos=[214, 3],
#      x=[214, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 4280] },
#    (ligand, contact, ligand)={ edge_index=[2, 4280] }
#  ),
#  HeteroData(
#    name='ed/3edp.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[217, 3],
#      x=[217, 1281]
#    },
#    ligand={
#      pos=[214, 3],
#      x=[214, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 4340] },
#    (ligand, contact, ligand)={ edge_index=[2, 4280] }
#  ),
#  HeteroData(
#    name='j3/2j3g.pdb2_1.dill',
#    center=[1, 3],
#    receptor={
#      pos=[217, 3],
#      x=[217, 1281]
#    },
#    ligand={
#      pos=[214, 3],
#      x=[214, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 4340] },
#    (ligand, contact, ligand)={ edge_index=[2, 4280] }
#  ),
#  HeteroData(
#    name='j3/2j3g.pdb2_2.dill',
#    center=[1, 3],
#    receptor={
#      pos=[218, 3],
#      x=[218, 1281]
#    },
#    ligand={
#      pos=[214, 3],
#      x=[214, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 4360] },
#    (ligand, contact, ligand)={ edge_index=[2, 4280] }
#  ),
#  HeteroData(
#    name='tn/3tnz.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[222, 3],
#      x=[222, 1281]
#    },
#    ligand={
#      pos=[221, 3],
#      x=[221, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 4440] },
#    (ligand, contact, ligand)={ edge_index=[2, 4420] }
#  ),
#  HeteroData(
#    name='aq/4aqa.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[237, 3],
#      x=[237, 1281]
#    },
#    ligand={
#      pos=[206, 3],
#      x=[206, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 4740] },
#    (ligand, contact, ligand)={ edge_index=[2, 4120] }
#  ),
#  HeteroData(
#    name='pj/3pj5.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[223, 3],
#      x=[223, 1281]
#    },
#    ligand={
#      pos=[223, 3],
#      x=[223, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 4460] },
#    (ligand, contact, ligand)={ edge_index=[2, 4460] }
#  ),
#  HeteroData(
#    name='sl/3slp.pdb1_1.dill',
#    center=[1, 3],
#    receptor={
#      pos=[226, 3],
#      x=[226, 1281]
#    },
#    ligand={
#      pos=[226, 3],
#      x=[226, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 4520] },
#    (ligand, contact, ligand)={ edge_index=[2, 4520] }
#  ),
#  HeteroData(
#    name='kq/3kqf.pdb2_1.dill',
#    center=[1, 3],
#    receptor={
#      pos=[253, 3],
#      x=[253, 1281]
#    },
#    ligand={
#      pos=[253, 3],
#      x=[253, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 5060] },
#    (ligand, contact, ligand)={ edge_index=[2, 5060] }
#  ),
#  HeteroData(
#    name='j3/4j3f.pdb5_5.dill',
#    center=[1, 3],
#    receptor={
#      pos=[259, 3],
#      x=[259, 1281]
#    },
#    ligand={
#      pos=[259, 3],
#      x=[259, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 5180] },
#    (ligand, contact, ligand)={ edge_index=[2, 5180] }
#  ),
#  HeteroData(
#    name='sl/3sll.pdb1_1.dill',
#    center=[1, 3],
#    receptor={
#      pos=[262, 3],
#      x=[262, 1281]
#    },
#    ligand={
#      pos=[258, 3],
#      x=[258, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 5240] },
#    (ligand, contact, ligand)={ edge_index=[2, 5160] }
#  ),
#  HeteroData(
#    name='sw/3swc.pdb3_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[261, 3],
#      x=[261, 1281]
#    },
#    ligand={
#      pos=[261, 3],
#      x=[261, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 5220] },
#    (ligand, contact, ligand)={ edge_index=[2, 5220] }
#  ),
#  HeteroData(
#    name='sl/3sll.pdb1_6.dill',
#    center=[1, 3],
#    receptor={
#      pos=[263, 3],
#      x=[263, 1281]
#    },
#    ligand={
#      pos=[260, 3],
#      x=[260, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 5260] },
#    (ligand, contact, ligand)={ edge_index=[2, 5200] }
#  ),
#  HeteroData(
#    name='sl/3sll.pdb1_12.dill',
#    center=[1, 3],
#    receptor={
#      pos=[263, 3],
#      x=[263, 1281]
#    },
#    ligand={
#      pos=[260, 3],
#      x=[260, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 5260] },
#    (ligand, contact, ligand)={ edge_index=[2, 5200] }
#  ),
#  HeteroData(
#    name='a9/2a9w.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[263, 3],
#      x=[263, 1281]
#    },
#    ligand={
#      pos=[263, 3],
#      x=[263, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 5260] },
#    (ligand, contact, ligand)={ edge_index=[2, 5260] }
#  ),
#  HeteroData(
#    name='ed/2ed3.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[265, 3],
#      x=[265, 1281]
#    },
#    ligand={
#      pos=[265, 3],
#      x=[265, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 5300] },
#    (ligand, contact, ligand)={ edge_index=[2, 5300] }
#  ),
#  HeteroData(
#    name='ed/2ed5.pdb2_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[265, 3],
#      x=[265, 1281]
#    },
#    ligand={
#      pos=[265, 3],
#      x=[265, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 5300] },
#    (ligand, contact, ligand)={ edge_index=[2, 5300] }
#  ),
#  HeteroData(
#    name='eb/2eb6.pdb1_3.dill',
#    center=[1, 3],
#    receptor={
#      pos=[267, 3],
#      x=[267, 1281]
#    },
#    ligand={
#      pos=[266, 3],
#      x=[266, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 5340] },
#    (ligand, contact, ligand)={ edge_index=[2, 5320] }
#  ),
#  HeteroData(
#    name='cf/3cf0.pdb1_6.dill',
#    center=[1, 3],
#    receptor={
#      pos=[281, 3],
#      x=[281, 1281]
#    },
#    ligand={
#      pos=[281, 3],
#      x=[281, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 5620] },
#    (ligand, contact, ligand)={ edge_index=[2, 5620] }
#  ),
#  HeteroData(
#    name='cf/3cf0.pdb2_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[281, 3],
#      x=[281, 1281]
#    },
#    ligand={
#      pos=[281, 3],
#      x=[281, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 5620] },
#    (ligand, contact, ligand)={ edge_index=[2, 5620] }
#  ),
#  HeteroData(
#    name='sk/1sk6.pdb2_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[454, 3],
#      x=[454, 1281]
#    },
#    ligand={
#      pos=[143, 3],
#      x=[143, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 9080] },
#    (ligand, contact, ligand)={ edge_index=[2, 2860] }
#  ),
#  HeteroData(
#    name='tn/3tnp.pdb1_2.dill',
#    center=[1, 3],
#    receptor={
#      pos=[334, 3],
#      x=[334, 1281]
#    },
#    ligand={
#      pos=[270, 3],
#      x=[270, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 6680] },
#    (ligand, contact, ligand)={ edge_index=[2, 5400] }
#  ),
#  HeteroData(
#    name='oi/3oix.pdb3_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[303, 3],
#      x=[303, 1281]
#    },
#    ligand={
#      pos=[302, 3],
#      x=[302, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 6060] },
#    (ligand, contact, ligand)={ edge_index=[2, 6040] }
#  ),
#  HeteroData(
#    name='b2/2b24.pdb1_9.dill',
#    center=[1, 3],
#    receptor={
#      pos=[440, 3],
#      x=[440, 1281]
#    },
#    ligand={
#      pos=[165, 3],
#      x=[165, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 8800] },
#    (ligand, contact, ligand)={ edge_index=[2, 3300] }
#  ),
#  HeteroData(
#    name='nq/2nq2.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[308, 3],
#      x=[308, 1281]
#    },
#    ligand={
#      pos=[300, 3],
#      x=[300, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 6160] },
#    (ligand, contact, ligand)={ edge_index=[2, 6000] }
#  ),
#  HeteroData(
#    name='p7/4p7c.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[312, 3],
#      x=[312, 1281]
#    },
#    ligand={
#      pos=[309, 3],
#      x=[309, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 6240] },
#    (ligand, contact, ligand)={ edge_index=[2, 6180] }
#  ),
#  HeteroData(
#    name='sk/1sk6.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[481, 3],
#      x=[481, 1281]
#    },
#    ligand={
#      pos=[143, 3],
#      x=[143, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 9620] },
#    (ligand, contact, ligand)={ edge_index=[2, 2860] }
#  ),
#  HeteroData(
#    name='sk/1sk6.pdb3_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[483, 3],
#      x=[483, 1281]
#    },
#    ligand={
#      pos=[143, 3],
#      x=[143, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 9660] },
#    (ligand, contact, ligand)={ edge_index=[2, 2860] }
#  ),
#  HeteroData(
#    name='hm/4hm1.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[446, 3],
#      x=[446, 1281]
#    },
#    ligand={
#      pos=[192, 3],
#      x=[192, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 8920] },
#    (ligand, contact, ligand)={ edge_index=[2, 3840] }
#  ),
#  HeteroData(
#    name='eb/4eba.pdb1_2.dill',
#    center=[1, 3],
#    receptor={
#      pos=[558, 3],
#      x=[558, 1281]
#    },
#    ligand={
#      pos=[81, 3],
#      x=[81, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 11160] },
#    (ligand, contact, ligand)={ edge_index=[2, 1620] }
#  ),
#  HeteroData(
#    name='eb/4eba.pdb3_1.dill',
#    center=[1, 3],
#    receptor={
#      pos=[578, 3],
#      x=[578, 1281]
#    },
#    ligand={
#      pos=[81, 3],
#      x=[81, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 11560] },
#    (ligand, contact, ligand)={ edge_index=[2, 1620] }
#  ),
#  HeteroData(
#    name='tn/1tnu.pdb6_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[346, 3],
#      x=[346, 1281]
#    },
#    ligand={
#      pos=[314, 3],
#      x=[314, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 6920] },
#    (ligand, contact, ligand)={ edge_index=[2, 6280] }
#  ),
#  HeteroData(
#    name='aq/4aqn.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[340, 3],
#      x=[340, 1281]
#    },
#    ligand={
#      pos=[338, 3],
#      x=[338, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 6800] },
#    (ligand, contact, ligand)={ edge_index=[2, 6760] }
#  ),
#  HeteroData(
#    name='pj/1pj1.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[340, 3],
#      x=[340, 1281]
#    },
#    ligand={
#      pos=[340, 3],
#      x=[340, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 6800] },
#    (ligand, contact, ligand)={ edge_index=[2, 6800] }
#  ),
#  HeteroData(
#    name='dm/5dm3.pdb7_1.dill',
#    center=[1, 3],
#    receptor={
#      pos=[386, 3],
#      x=[386, 1281]
#    },
#    ligand={
#      pos=[374, 3],
#      x=[374, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 7720] },
#    (ligand, contact, ligand)={ edge_index=[2, 7480] }
#  ),
#  HeteroData(
#    name='dm/1dm3.pdb1_4.dill',
#    center=[1, 3],
#    receptor={
#      pos=[388, 3],
#      x=[388, 1281]
#    },
#    ligand={
#      pos=[388, 3],
#      x=[388, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 7760] },
#    (ligand, contact, ligand)={ edge_index=[2, 7760] }
#  ),
#  HeteroData(
#    name='b2/1b26.pdb1_3.dill',
#    center=[1, 3],
#    receptor={
#      pos=[409, 3],
#      x=[409, 1281]
#    },
#    ligand={
#      pos=[409, 3],
#      x=[409, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 8180] },
#    (ligand, contact, ligand)={ edge_index=[2, 8180] }
#  ),
#  HeteroData(
#    name='b2/1b26.pdb1_9.dill',
#    center=[1, 3],
#    receptor={
#      pos=[409, 3],
#      x=[409, 1281]
#    },
#    ligand={
#      pos=[409, 3],
#      x=[409, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 8180] },
#    (ligand, contact, ligand)={ edge_index=[2, 8180] }
#  ),
#  HeteroData(
#    name='aq/4aq2.pdb1_10.dill',
#    center=[1, 3],
#    receptor={
#      pos=[421, 3],
#      x=[421, 1281]
#    },
#    ligand={
#      pos=[419, 3],
#      x=[419, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 8420] },
#    (ligand, contact, ligand)={ edge_index=[2, 8380] }
#  ),
#  HeteroData(
#    name='b2/2b24.pdb1_8.dill',
#    center=[1, 3],
#    receptor={
#      pos=[440, 3],
#      x=[440, 1281]
#    },
#    ligand={
#      pos=[440, 3],
#      x=[440, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 8800] },
#    (ligand, contact, ligand)={ edge_index=[2, 8800] }
#  ),
#  HeteroData(
#    name='hm/3hmu.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[464, 3],
#      x=[464, 1281]
#    },
#    ligand={
#      pos=[460, 3],
#      x=[460, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 9280] },
#    (ligand, contact, ligand)={ edge_index=[2, 9200] }
#  ),
#  HeteroData(
#    name='hm/2hmf.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[464, 3],
#      x=[464, 1281]
#    },
#    ligand={
#      pos=[464, 3],
#      x=[464, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 9280] },
#    (ligand, contact, ligand)={ edge_index=[2, 9280] }
#  ),
#  HeteroData(
#    name='hm/2hmf.pdb1_1.dill',
#    center=[1, 3],
#    receptor={
#      pos=[464, 3],
#      x=[464, 1281]
#    },
#    ligand={
#      pos=[464, 3],
#      x=[464, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 9280] },
#    (ligand, contact, ligand)={ edge_index=[2, 9280] }
#  ),
#  HeteroData(
#    name='tn/4tnp.pdb1_1.dill',
#    center=[1, 3],
#    receptor={
#      pos=[481, 3],
#      x=[481, 1281]
#    },
#    ligand={
#      pos=[479, 3],
#      x=[479, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 9620] },
#    (ligand, contact, ligand)={ edge_index=[2, 9580] }
#  ),
#  HeteroData(
#    name='kq/3kqx.pdb1_11.dill',
#    center=[1, 3],
#    receptor={
#      pos=[509, 3],
#      x=[509, 1281]
#    },
#    ligand={
#      pos=[510, 3],
#      x=[510, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 10180] },
#    (ligand, contact, ligand)={ edge_index=[2, 10200] }
#  ),
#  HeteroData(
#    name='kq/3kqx.pdb1_10.dill',
#    center=[1, 3],
#    receptor={
#      pos=[514, 3],
#      x=[514, 1281]
#    },
#    ligand={
#      pos=[510, 3],
#      x=[510, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 10280] },
#    (ligand, contact, ligand)={ edge_index=[2, 10200] }
#  ),
#  HeteroData(
#    name='pj/4pj1.pdb1_55.dill',
#    center=[1, 3],
#    receptor={
#      pos=[526, 3],
#      x=[526, 1281]
#    },
#    ligand={
#      pos=[526, 3],
#      x=[526, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 10520] },
#    (ligand, contact, ligand)={ edge_index=[2, 10520] }
#  ),
#  HeteroData(
#    name='pj/1pjl.pdb1_1.dill',
#    center=[1, 3],
#    receptor={
#      pos=[537, 3],
#      x=[537, 1281]
#    },
#    ligand={
#      pos=[537, 3],
#      x=[537, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 10740] },
#    (ligand, contact, ligand)={ edge_index=[2, 10740] }
#  ),
#  HeteroData(
#    name='pj/1pjl.pdb2_2.dill',
#    center=[1, 3],
#    receptor={
#      pos=[537, 3],
#      x=[537, 1281]
#    },
#    ligand={
#      pos=[537, 3],
#      x=[537, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 10740] },
#    (ligand, contact, ligand)={ edge_index=[2, 10740] }
#  ),
#  HeteroData(
#    name='eb/4eba.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[585, 3],
#      x=[585, 1281]
#    },
#    ligand={
#      pos=[558, 3],
#      x=[558, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 11700] },
#    (ligand, contact, ligand)={ edge_index=[2, 11160] }
#  ),
#  HeteroData(
#    name='a9/3a9s.pdb1_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[589, 3],
#      x=[589, 1281]
#    },
#    ligand={
#      pos=[589, 3],
#      x=[589, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 11780] },
#    (ligand, contact, ligand)={ edge_index=[2, 11780] }
#  ),
#  HeteroData(
#    name='oi/4oip.pdb1_3.dill',
#    center=[1, 3],
#    receptor={
#      pos=[1112, 3],
#      x=[1112, 1281]
#    },
#    ligand={
#      pos=[227, 3],
#      x=[227, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 22240] },
#    (ligand, contact, ligand)={ edge_index=[2, 4540] }
#  ),
#  HeteroData(
#    name='a9/1a9x.pdb4_0.dill',
#    center=[1, 3],
#    receptor={
#      pos=[1058, 3],
#      x=[1058, 1281]
#    },
#    ligand={
#      pos=[378, 3],
#      x=[378, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 21160] },
#    (ligand, contact, ligand)={ edge_index=[2, 7560] }
#  ),
#  HeteroData(
#    name='p7/1p7z.pdb1_1.dill',
#    center=[1, 3],
#    receptor={
#      pos=[727, 3],
#      x=[727, 1281]
#    },
#    ligand={
#      pos=[727, 3],
#      x=[727, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 14540] },
#    (ligand, contact, ligand)={ edge_index=[2, 14540] }
#  ),
#  HeteroData(
#    name='oi/4oip.pdb1_8.dill',
#    center=[1, 3],
#    receptor={
#      pos=[1112, 3],
#      x=[1112, 1281]
#    },
#    ligand={
#      pos=[346, 3],
#      x=[346, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 22240] },
#    (ligand, contact, ligand)={ edge_index=[2, 6920] }
#  ),
#  HeteroData(
#    name='ww/2ww2.pdb1_1.dill',
#    center=[1, 3],
#    receptor={
#      pos=[737, 3],
#      x=[737, 1281]
#    },
#    ligand={
#      pos=[737, 3],
#      x=[737, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 14740] },
#    (ligand, contact, ligand)={ edge_index=[2, 14740] }
#  ),
#  HeteroData(
#    name='ww/2ww2.pdb1_2.dill',
#    center=[1, 3],
#    receptor={
#      pos=[737, 3],
#      x=[737, 1281]
#    },
#    ligand={
#      pos=[737, 3],
#      x=[737, 1281]
#    },
#    (receptor, contact, receptor)={ edge_index=[2, 14740] },
#    (ligand, contact, ligand)={ edge_index=[2, 14740] }
#  )]

# %%
[comp["receptor"].pos.shape[0] + comp["ligand"].pos.shape[0] for comp in loaders["test"]]
# Out:
# [122,
#  126,
#  156,
#  159,
#  193,
#  207,
#  214,
#  219,
#  220,
#  222,
#  225,
#  234,
#  235,
#  237,
#  248,
#  255,
#  258,
#  259,
#  264,
#  265,
#  278,
#  280,
#  280,
#  286,
#  296,
#  298,
#  298,
#  300,
#  300,
#  302,
#  306,
#  308,
#  310,
#  311,
#  320,
#  329,
#  334,
#  338,
#  340,
#  344,
#  393,
#  395,
#  427,
#  428,
#  431,
#  431,
#  432,
#  443,
#  443,
#  446,
#  452,
#  506,
#  518,
#  520,
#  522,
#  523,
#  523,
#  526,
#  530,
#  530,
#  533,
#  562,
#  562,
#  597,
#  604,
#  605,
#  605,
#  608,
#  621,
#  624,
#  626,
#  638,
#  639,
#  659,
#  660,
#  678,
#  680,
#  760,
#  776,
#  818,
#  818,
#  840,
#  880,
#  924,
#  928,
#  928,
#  960,
#  1019,
#  1024,
#  1052,
#  1074,
#  1074,
#  1143,
#  1178,
#  1339,
#  1436,
#  1454,
#  1458,
#  1474,
#  1474]
