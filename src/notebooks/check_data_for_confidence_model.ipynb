# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

# %%
os.chdir('/data/rsg/nlp/sdobers/amine/diffdock-protein/src')

# %%
from filtering.dataset import CondfidenceBindingDataset

# %%
dataset = CondfidenceBindingDataset("val", "/data/rsg/nlp/sdobers/DIPS/confidence_full")
# Out:
# 100%|██████████| 7/7 [00:01<00:00,  3.59it/s]

# %%
for i, (data, rmsd) in enumerate(dataset):
    if i >=5: 
        break
    print(data["name"])
    print(data["ligand"].pos)
    print('-----')
# Out:
# u5/4u5p.pdb1_1.dill
# tensor([[ 2.0675e+00,  1.8246e-01,  2.0137e+01],
#         [-8.9097e-01,  7.8347e-01,  1.7847e+01],
#         [-2.9559e+00, -2.3638e+00,  1.7134e+01],
#         [-5.8358e+00, -2.7094e+00,  1.4662e+01],
#         [-7.8422e+00, -5.9286e+00,  1.4884e+01],
#         [-1.0371e+01, -6.5239e+00,  1.2080e+01],
#         [-1.2965e+01, -9.1975e+00,  1.2927e+01],
#         [-1.6220e+01, -1.0776e+01,  1.1726e+01],
#         [-1.9256e+01, -8.9907e+00,  1.3156e+01],
#         [-1.9950e+01, -9.7319e+00,  1.6817e+01],
#         [-1.7001e+01, -1.2115e+01,  1.7024e+01],
#         [-1.5957e+01, -1.0687e+01,  2.0393e+01],
#         [-1.7903e+01, -9.6197e+00,  2.3464e+01],
#         [-1.6747e+01, -6.6479e+00,  2.5553e+01],
#         [-1.5254e+01, -9.1532e+00,  2.8034e+01],
#         [-1.3391e+01, -1.0894e+01,  2.5197e+01],
#         [-1.1969e+01, -7.5719e+00,  2.3989e+01],
#         [-1.0955e+01, -6.5929e+00,  2.7496e+01],
#         [-9.1073e+00, -9.8760e+00,  2.8053e+01],
# ...
